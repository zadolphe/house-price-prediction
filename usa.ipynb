# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
us_df = pd.read_csv("C:/Users/owner/Desktop/cpsc599/project/zillow-economics/.csv")
us_rental_df = pd.read_csv("C:/Users/owner/Desktop/cpsc599/project/Metro_ZORI_AllHomesPlusMultifamily_SSA-rental.csv")

# %%
us_df.head(10)
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
# 5    394974         5                    Philadelphia, PA        Msa
# 6    394692         6                         Houston, TX        Msa
# 7    395209         7                      Washington, DC        Msa
# 8    394856         8           Miami-Fort Lauderdale, FL        Msa
# 9    394347         9                         Atlanta, GA        Msa
#
#   StateName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  \
# 0       NaN    127215.0    127559.0    127921.0    128658.0    129402.0  ...
# ...

# %%
us_df.shape
# Out:
# (907, 270)

# %%
us_df.groupby('StateName')['StateName'].agg('count')
# Out:
# StateName
# AK     4
# AL    21
# AR    20
# AZ    11
# CA    34
# CO    17
# CT     5
# DC     1
# DE     2
# FL    29
# GA    37
# HI     4
# IA    21
# ID    13
# IL    27
# IN    36
# KS    20
# KY    20
# LA    17
# MA     7
# MD     6
# ME     4
# MI    33
# MN    20
# MO    25
# MS    18
# MT     7
# NC    39
# ND     8
# NE    12
# NH     6
# NJ     4
# NM    16
# NV     9
# NY    26
# OH    45
# OK    21
# OR    20
# PA    34
# RI     1
# SC    15
# SD    10
# TN    26
# TX    66
# UT     9
# VA    12
# VT     4
# WA    20
# WI    24
# WV    11
# WY     9
# Name: StateName, dtype: int64

# %%
us_df2 = us_df.iloc[][5:]
us_df2.head()
# Out:
#    RegionID  SizeRank                 RegionName RegionType StateName  \
# 5    394974         5           Philadelphia, PA        Msa        PA
# 6    394692         6                Houston, TX        Msa        TX
# 7    395209         7             Washington, DC        Msa        DC
# 8    394856         8  Miami-Fort Lauderdale, FL        Msa        FL
# 9    394347         9                Atlanta, GA        Msa        GA
#
#    2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  \
# 5    129210.0    129643.0    129903.0    130549.0    131072.0  ...
# 6    125299.0    125376.0    125258.0    125376.0    125383.0  ...
# 7    191888.0    192133.0    192510.0    193310.0    194422.0  ...
# 8    126285.0    126751.0    127167.0    127986.0    128660.0  ...
# 9    153054.0    153564.0    154087.0    155148.0    156185.0  ...
#
#    2021-04-30  2021-05-31  2021-06-30  2021-07-31  2021-08-31  2021-09-30  \
# ...

# %%
us_df2.shape
# Out:
# (255, 270)
