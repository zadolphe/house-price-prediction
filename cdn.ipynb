# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import altair as alt
import statsmodels.api as sm
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10) 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
cdn_df = pd.read_csv("C:/Users/owner/Desktop/cpsc599/project/46100057.csv")
#data fromm: https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=4610005701 "Number of residential properties sold and sale price by property type and period of construction"

us_df = pd.read_csv("C:/Users/owner/Desktop/cpsc599/project/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
us_rental_df = pd.read_csv("C:/Users/owner/Desktop/cpsc599/project/Metro_ZORI_AllHomesPlusMultifamily_SSA-rental.csv")
#cdn_rental_df = pd.read_csv("C:/Users/owner/Desktop/cpsc599/project/34100133-rent.csv")
cdn_df
# Out:
#        REF_DATE                                                GEO  \
# 0          2018                                        Nova Scotia
# 1          2018                                        Nova Scotia
# 2          2018                                        Nova Scotia
# 3          2018                                        Nova Scotia
# 4          2018                                        Nova Scotia
# ...         ...                                                ...
# 15997      2018  Outside of census metropolitan and agglomerati...
# 15998      2018  Outside of census metropolitan and agglomerati...
# 15999      2018  Outside of census metropolitan and agglomerati...
# 16000      2018  Outside of census metropolitan and agglomerati...
# 16001      2018  Outside of census metropolitan and agglomerati...
#
#              DGUID              Sale type  \
# 0      2016A000212  Total, all sale types
# 1      2016A000212  Total, all sale types
# 2      2016A000212  Total, all sale types
# 3      2016A000212  Total, all sale types
# 4      2016A000212  Total, all sale types
# ...            ...                    ...
# 15997          NaN            Market sale
# 15998          NaN            Market sale
# 15999          NaN            Market sale
# 16000          NaN            Market sale
# 16001          NaN            Market sale
#
#                                 Property characteristics  \
# 0                              Total, all property types
# 1                              Total, all property types
# 2                              Total, all property types
# 3                              Total, all property types
# 4                              Total, all property types
# ...                                                  ...
# 15997  Period of construction not applicable (vacant ...
# 15998  Period of construction not applicable (vacant ...
# 15999  Period of construction not applicable (vacant ...
# 16000  Period of construction not applicable (vacant ...
# 16001  Period of construction not applicable (vacant ...
#
#                                   Estimates      UOM  UOM_ID SCALAR_FACTOR  \
# 0                 Number of properties sold   Number     223         units
# 1                     Sale type, percentage  Percent     239         units
# 2      Property characteristics, percentage  Percent     239         units
# 3                  Average number of buyers   Number     223         units
# 4                        Average sale price  Dollars      81         units
# ...                                     ...      ...     ...           ...
# 15997                 Sale type, percentage  Percent     239         units
# 15998  Property characteristics, percentage  Percent     239         units
# 15999              Average number of buyers   Number     223         units
# 16000                    Average sale price  Dollars      81         units
# 16001                     Median sale price  Dollars      81         units
#
#        SCALAR_ID       VECTOR COORDINATE     VALUE STATUS  SYMBOL  TERMINATED  \
# 0              0  v1278317597    1.1.1.1   25390.0    NaN     NaN         NaN
# 1              0  v1278317598    1.1.1.2     100.0    NaN     NaN         NaN
# 2              0  v1278317599    1.1.1.3     100.0    NaN     NaN         NaN
# 3              0  v1278317600    1.1.1.4       1.6    NaN     NaN         NaN
# 4              0  v1278317601    1.1.1.5  200000.0    NaN     NaN         NaN
# ...          ...          ...        ...       ...    ...     ...         ...
# 15997          0  v1278333594  44.3.21.2      69.2    NaN     NaN         NaN
# 15998          0  v1278333595  44.3.21.3      16.8    NaN     NaN         NaN
# 15999          0  v1278333596  44.3.21.4       1.6    NaN     NaN         NaN
# 16000          0  v1278333597  44.3.21.5  220000.0    NaN     NaN         NaN
# 16001          0  v1278333598  44.3.21.6  125000.0    NaN     NaN         NaN
#
#        DECIMALS
# 0             0
# 1             1
# 2             1
# 3             1
# 4             0
# ...         ...
# 15997         1
# 15998         1
# 15999         1
# 16000         0
# 16001         0
#
# [16002 rows x 17 columns]

# %%
print("Canadian df ",cdn_df.shape)
#this is the number of rows and columns
# Out:
# Canadian df  (16002, 17)

# %% [markdown]
# It looks like the columns have price changes over time as a time series based df

# %%
#let's get a look at what the values in the column for the Caandian dataset for region to see what the breakdown might look like 
#for the makeup of houses are around the country
cdn_df.groupby('GEO')['GEO'].agg('count')
# Out:
# GEO
# Abbotsford - Mission, Census metropolitan area (CMA)                             360
# Bathurst, Census agglomeration (CA)                                              378
# British Columbia                                                                 360
# Campbell River, Census agglomeration (CA)                                        360
# Campbellton (New Brunswick part), Census agglomeration (CA) – provincial part    378
# Cape Breton, Census agglomeration (CA)                                           360
# Chilliwack, Census agglomeration (CA)                                            360
# Courtenay, Census agglomeration (CA)                                             360
# Cranbrook, Census agglomeration (CA)                                             360
# Dawson Creek, Census agglomeration (CA)                                          360
# Duncan, Census agglomeration (CA)                                                360
# Edmundston, Census agglomeration (CA)                                            378
# Fort St. John, Census agglomeration (CA)                                         360
# Fredericton, Census agglomeration (CA)                                           378
# Halifax, Census metropolitan area (CMA)                                          360
# Kamloops, Census agglomeration (CA)                                              360
# Kelowna, Census metropolitan area (CMA)                                          360
# Kentville, Census agglomeration (CA)                                             360
# Miramichi, Census agglomeration (CA)                                             378
# Moncton, Census metropolitan area (CMA)                                          378
# Nanaimo, Census agglomeration (CA)                                               360
# Nelson, Census agglomeration (CA)                                                360
# New Brunswick                                                                    378
# New Glasgow, Census agglomeration (CA)                                           360
# Nova Scotia                                                                      360
# Outside of census metropolitan and agglomeration areas, British Columbia         360
# Outside of census metropolitan and agglomeration areas, New Brunswick            378
# Outside of census metropolitan and agglomeration areas, Nova Scotia              360
# Parksville, Census agglomeration (CA)                                            360
# Penticton, Census agglomeration (CA)                                             360
# Port Alberni, Census agglomeration (CA)                                          360
# Powell River, Census agglomeration (CA)                                          360
# Prince George, Census agglomeration (CA)                                         360
# Prince Rupert, Census agglomeration (CA)                                         360
# Quesnel, Census agglomeration (CA)                                               360
# Saint John, Census metropolitan area (CMA)                                       378
# Salmon Arm, Census agglomeration (CA)                                            360
# Squamish, Census agglomeration (CA)                                              360
# Terrace, Census agglomeration (CA)                                               360
# Truro, Census agglomeration (CA)                                                 360
# Vancouver, Census metropolitan area (CMA)                                        360
# Vernon, Census agglomeration (CA)                                                360
# Victoria, Census metropolitan area (CMA)                                         360
# Williams Lake, Census agglomeration (CA)                                         360
# Name: GEO, dtype: int64

# %% [markdown]
# make a pie graph or something out of this

# %%
cdn_df.groupby('GEO')['GEO'].agg('count').unique()
# Out:
# array([360, 378], dtype=int64)

# %%
#so there are 378 districts - we need to encode these
#also note that there is also only one ref date so delete this
cdn_df.groupby('REF_DATE')['REF_DATE'].agg('count').shape
# Out:
# (1,)

# %%
cdn_df2 = cdn_df.drop(['DGUID', 'TERMINATED','SYMBOL', 'STATUS', 'VECTOR', 'SCALAR_ID', 'REF_DATE', 'SCALAR_FACTOR', 'DECIMALS'], axis='columns')
cdn_df2.tail()
# Out:
#                                                      GEO    Sale type  \
# 15997  Outside of census metropolitan and agglomerati...  Market sale
# 15998  Outside of census metropolitan and agglomerati...  Market sale
# 15999  Outside of census metropolitan and agglomerati...  Market sale
# 16000  Outside of census metropolitan and agglomerati...  Market sale
# 16001  Outside of census metropolitan and agglomerati...  Market sale
#
#                                 Property characteristics  \
# 15997  Period of construction not applicable (vacant ...
# 15998  Period of construction not applicable (vacant ...
# 15999  Period of construction not applicable (vacant ...
# 16000  Period of construction not applicable (vacant ...
# 16001  Period of construction not applicable (vacant ...
#
#                                   Estimates      UOM  UOM_ID COORDINATE  \
# 15997                 Sale type, percentage  Percent     239  44.3.21.2
# 15998  Property characteristics, percentage  Percent     239  44.3.21.3
# 15999              Average number of buyers   Number     223  44.3.21.4
# 16000                    Average sale price  Dollars      81  44.3.21.5
# 16001                     Median sale price  Dollars      81  44.3.21.6
#
#           VALUE
# 15997      69.2
# 15998      16.8
# 15999       1.6
# 16000  220000.0
# 16001  125000.0

# %%
#WE WILL USE COORDINATE INSTEAD OF GEO FOR REGRESSION THEN REFERENCE THAT VALUE 
#CREATE REGRESSION DF
r_df = cdn_df2.drop(['GEO'], axis='columns')
r_df
# Out:
#                    Sale type  \
# 0      Total, all sale types
# 1      Total, all sale types
# 2      Total, all sale types
# 3      Total, all sale types
# 4      Total, all sale types
# ...                      ...
# 15997            Market sale
# 15998            Market sale
# 15999            Market sale
# 16000            Market sale
# 16001            Market sale
#
#                                 Property characteristics  \
# 0                              Total, all property types
# 1                              Total, all property types
# 2                              Total, all property types
# 3                              Total, all property types
# 4                              Total, all property types
# ...                                                  ...
# 15997  Period of construction not applicable (vacant ...
# 15998  Period of construction not applicable (vacant ...
# 15999  Period of construction not applicable (vacant ...
# 16000  Period of construction not applicable (vacant ...
# 16001  Period of construction not applicable (vacant ...
#
#                                   Estimates      UOM  UOM_ID COORDINATE  \
# 0                 Number of properties sold   Number     223    1.1.1.1
# 1                     Sale type, percentage  Percent     239    1.1.1.2
# 2      Property characteristics, percentage  Percent     239    1.1.1.3
# 3                  Average number of buyers   Number     223    1.1.1.4
# 4                        Average sale price  Dollars      81    1.1.1.5
# ...                                     ...      ...     ...        ...
# 15997                 Sale type, percentage  Percent     239  44.3.21.2
# 15998  Property characteristics, percentage  Percent     239  44.3.21.3
# 15999              Average number of buyers   Number     223  44.3.21.4
# 16000                    Average sale price  Dollars      81  44.3.21.5
# 16001                     Median sale price  Dollars      81  44.3.21.6
#
#           VALUE
# 0       25390.0
# 1         100.0
# 2         100.0
# 3           1.6
# 4      200000.0
# ...         ...
# 15997      69.2
# 15998      16.8
# 15999       1.6
# 16000  220000.0
# 16001  125000.0
#
# [16002 rows x 7 columns]

# %%
#we need a sales price df not any of the other estimates, we can use these others later 
r_df
# Out:
#                    Sale type  \
# 0      Total, all sale types
# 1      Total, all sale types
# 2      Total, all sale types
# 3      Total, all sale types
# 4      Total, all sale types
# ...                      ...
# 15997            Market sale
# 15998            Market sale
# 15999            Market sale
# 16000            Market sale
# 16001            Market sale
#
#                                 Property characteristics  \
# 0                              Total, all property types
# 1                              Total, all property types
# 2                              Total, all property types
# 3                              Total, all property types
# 4                              Total, all property types
# ...                                                  ...
# 15997  Period of construction not applicable (vacant ...
# 15998  Period of construction not applicable (vacant ...
# 15999  Period of construction not applicable (vacant ...
# 16000  Period of construction not applicable (vacant ...
# 16001  Period of construction not applicable (vacant ...
#
#                                   Estimates      UOM  UOM_ID COORDINATE  \
# 0                 Number of properties sold   Number     223    1.1.1.1
# 1                     Sale type, percentage  Percent     239    1.1.1.2
# 2      Property characteristics, percentage  Percent     239    1.1.1.3
# 3                  Average number of buyers   Number     223    1.1.1.4
# 4                        Average sale price  Dollars      81    1.1.1.5
# ...                                     ...      ...     ...        ...
# 15997                 Sale type, percentage  Percent     239  44.3.21.2
# 15998  Property characteristics, percentage  Percent     239  44.3.21.3
# 15999              Average number of buyers   Number     223  44.3.21.4
# 16000                    Average sale price  Dollars      81  44.3.21.5
# 16001                     Median sale price  Dollars      81  44.3.21.6
#
#           VALUE
# 0       25390.0
# 1         100.0
# 2         100.0
# 3           1.6
# 4      200000.0
# ...         ...
# 15997      69.2
# 15998      16.8
# 15999       1.6
# 16000  220000.0
# 16001  125000.0
#
# [16002 rows x 7 columns]

# %%
cdn_df.groupby('GEO')['GEO'].agg('count').shape
# Out:
# (44,)

# %% [markdown]
# 40*1476 = 59,040 which is the number of rows we have in our dataset so this makes sense

# %% [markdown]
# Lets do some data cleaning

# %%
#check for null values 
cdn_df2.isnull().sum()
# Out:
# GEO                            0
# Sale type                      0
# Property characteristics       0
# Estimates                      0
# UOM                            0
# UOM_ID                         0
# COORDINATE                     0
# VALUE                       2782
# dtype: int64

# %%
#we have lots of null values in the value of house price but I believe this column value is measuring different metrics based on the "Estimates"
#column, let's break this down and check
cdn_df2.groupby('Estimates')['Estimates'].agg('count')
# Out:
# Estimates
# Average number of buyers                2667
# Average sale price                      2667
# Median sale price                       2667
# Number of properties sold               2667
# Property characteristics, percentage    2667
# Sale type, percentage                   2667
# Name: Estimates, dtype: int64

# %% [markdown]
# So we have here 6 features being measured: Avg number of buyers, avg sale price, median sale price, number of properties sold, property characteristics as percentage, sale type as percentage. And there is about 2782 null values in these measures. Since we have plenty of
# to work with still we will drop these values

# %%
cdn_df2 = cdn_df2.dropna()
cdn_df2.isnull().sum()
# Out:
# GEO                         0
# Sale type                   0
# Property characteristics    0
# Estimates                   0
# UOM                         0
# UOM_ID                      0
# COORDINATE                  0
# VALUE                       0
# dtype: int64

# %%
cdn_df2.shape
# Out:
# (13220, 8)

# %%
cdn_df3 = cdn_df2.drop(['UOM_ID', 'UOM', 'COORDINATE'],'columns')
#we will use this to get other estimate values and take their avg and then we will use this as other features in prediction
#first get df for estimate then calc avg for each region
avg_buyers_mask = cdn_df3["Estimates"]=='Average number of buyers'
avg_buyers = cdn_df3[avg_buyers_mask]
prop_sold_mask = cdn_df3["Estimates"]=='Number of properties sold'
prop_sold = cdn_df3[prop_sold_mask]
prop_char_mask = cdn_df3['Estimates']=='Property characteristics, percentage'
prop_char = cdn_df3[prop_char_mask]
sale_type_mask = cdn_df3['Estimates']=='Sale type, percentage'
sale_type = cdn_df3[sale_type_mask]
sale_type
# Out:
#                                                      GEO  \
# 1                                            Nova Scotia
# 7                                            Nova Scotia
# 13                                           Nova Scotia
# 19                                           Nova Scotia
# 25                                           Nova Scotia
# ...                                                  ...
# 15973  Outside of census metropolitan and agglomerati...
# 15979  Outside of census metropolitan and agglomerati...
# 15985  Outside of census metropolitan and agglomerati...
# 15991  Outside of census metropolitan and agglomerati...
# 15997  Outside of census metropolitan and agglomerati...
#
#                    Sale type  \
# 1      Total, all sale types
# 7      Total, all sale types
# 13     Total, all sale types
# 19     Total, all sale types
# 25     Total, all sale types
# ...                      ...
# 15973            Market sale
# 15979            Market sale
# 15985            Market sale
# 15991            Market sale
# 15997            Market sale
#
#                                 Property characteristics  \
# 1                              Total, all property types
# 7                                  Single-detached house
# 13                                   Semi-detached house
# 19                                             Row house
# 25                                 Condominium apartment
# ...                                                  ...
# 15973                                       2001 to 2005
# 15979                                       2006 to 2010
# 15985                                       2011 to 2015
# 15991                           2016 to reference period
# 15997  Period of construction not applicable (vacant ...
#
#                    Estimates  VALUE
# 1      Sale type, percentage  100.0
# 7      Sale type, percentage  100.0
# 13     Sale type, percentage  100.0
# 19     Sale type, percentage  100.0
# 25     Sale type, percentage  100.0
# ...                      ...    ...
# 15973  Sale type, percentage   75.2
# 15979  Sale type, percentage   78.6
# 15985  Sale type, percentage   76.0
# 15991  Sale type, percentage   80.5
# 15997  Sale type, percentage   69.2
#
# [2586 rows x 5 columns]

# %%
#lets inspect a couple columns more 
sale_price_mask = cdn_df3["Estimates"]=='Average sale price'
#sale_price_mask.head()
#avg_sale_price = cdn_df3[avg_sale_price]
avg_sale_price = cdn_df3[sale_price_mask]
avg_sale_price.head(10)
# Out:
#             GEO              Sale type  \
# 4   Nova Scotia  Total, all sale types
# 10  Nova Scotia  Total, all sale types
# 16  Nova Scotia  Total, all sale types
# 22  Nova Scotia  Total, all sale types
# 28  Nova Scotia  Total, all sale types
# 34  Nova Scotia  Total, all sale types
# 40  Nova Scotia  Total, all sale types
# 46  Nova Scotia  Total, all sale types
# 52  Nova Scotia  Total, all sale types
# 58  Nova Scotia  Total, all sale types
#
#                     Property characteristics           Estimates     VALUE
# 4                  Total, all property types  Average sale price  200000.0
# 10                     Single-detached house  Average sale price  220000.0
# 16                       Semi-detached house  Average sale price  200000.0
# 22                                 Row house  Average sale price  280000.0
# 28                     Condominium apartment  Average sale price  250000.0
# 34                              Mobile homes  Average sale price   68000.0
# 40                       Other property type  Average sale price  350000.0
# 46  Property with multiple residential units  Average sale price  430000.0
# 52                               Vacant land  Average sale price   62000.0
# 58        Total, all periods of construction  Average sale price  200000.0

# %%
#lets use this df with sales price for regression df
#what is this UMO_ID column?
r_df_sales = avg_sale_price
r_df_sales = r_df_sales.rename(columns={"VALUE": "PRICE"})
r_df_sales
# Out:
#                                                      GEO  \
# 4                                            Nova Scotia
# 10                                           Nova Scotia
# 16                                           Nova Scotia
# 22                                           Nova Scotia
# 28                                           Nova Scotia
# ...                                                  ...
# 15976  Outside of census metropolitan and agglomerati...
# 15982  Outside of census metropolitan and agglomerati...
# 15988  Outside of census metropolitan and agglomerati...
# 15994  Outside of census metropolitan and agglomerati...
# 16000  Outside of census metropolitan and agglomerati...
#
#                    Sale type  \
# 4      Total, all sale types
# 10     Total, all sale types
# 16     Total, all sale types
# 22     Total, all sale types
# 28     Total, all sale types
# ...                      ...
# 15976            Market sale
# 15982            Market sale
# 15988            Market sale
# 15994            Market sale
# 16000            Market sale
#
#                                 Property characteristics           Estimates  \
# 4                              Total, all property types  Average sale price
# 10                                 Single-detached house  Average sale price
# 16                                   Semi-detached house  Average sale price
# 22                                             Row house  Average sale price
# 28                                 Condominium apartment  Average sale price
# ...                                                  ...                 ...
# 15976                                       2001 to 2005  Average sale price
# 15982                                       2006 to 2010  Average sale price
# 15988                                       2011 to 2015  Average sale price
# 15994                           2016 to reference period  Average sale price
# 16000  Period of construction not applicable (vacant ...  Average sale price
#
#           PRICE
# 4      200000.0
# 10     220000.0
# 16     200000.0
# 22     280000.0
# 28     250000.0
# ...         ...
# 15976  590000.0
# 15982  530000.0
# 15988  640000.0
# 15994  470000.0
# 16000  220000.0
#
# [1586 rows x 5 columns]

# %%
#lets create some dummy variables for our categorical features
X = r_df_sales[['GEO', 'Sale type', 'Property characteristics']]
X = pd.get_dummies(data=X, drop_first=True)
X
# Out:
#        GEO_Bathurst, Census agglomeration (CA)  GEO_British Columbia  \
# 4                                            0                     0
# 10                                           0                     0
# 16                                           0                     0
# 22                                           0                     0
# 28                                           0                     0
# ...                                        ...                   ...
# 15976                                        0                     0
# 15982                                        0                     0
# 15988                                        0                     0
# 15994                                        0                     0
# 16000                                        0                     0
#
#        GEO_Campbell River, Census agglomeration (CA)  \
# 4                                                  0
# 10                                                 0
# 16                                                 0
# 22                                                 0
# 28                                                 0
# ...                                              ...
# 15976                                              0
# 15982                                              0
# 15988                                              0
# 15994                                              0
# 16000                                              0
#
#        GEO_Campbellton (New Brunswick part), Census agglomeration (CA) – provincial part  \
# 4                                                      0
# 10                                                     0
# 16                                                     0
# 22                                                     0
# 28                                                     0
# ...                                                  ...
# 15976                                                  0
# 15982                                                  0
# 15988                                                  0
# 15994                                                  0
# 16000                                                  0
#
#        GEO_Cape Breton, Census agglomeration (CA)  \
# 4                                               0
# 10                                              0
# 16                                              0
# 22                                              0
# 28                                              0
# ...                                           ...
# 15976                                           0
# 15982                                           0
# 15988                                           0
# 15994                                           0
# 16000                                           0
#
#        GEO_Chilliwack, Census agglomeration (CA)  \
# 4                                              0
# 10                                             0
# 16                                             0
# 22                                             0
# 28                                             0
# ...                                          ...
# 15976                                          0
# 15982                                          0
# 15988                                          0
# 15994                                          0
# 16000                                          0
#
#        GEO_Courtenay, Census agglomeration (CA)  \
# 4                                             0
# 10                                            0
# 16                                            0
# 22                                            0
# 28                                            0
# ...                                         ...
# 15976                                         0
# 15982                                         0
# 15988                                         0
# 15994                                         0
# 16000                                         0
#
#        GEO_Cranbrook, Census agglomeration (CA)  \
# 4                                             0
# 10                                            0
# 16                                            0
# 22                                            0
# 28                                            0
# ...                                         ...
# 15976                                         0
# 15982                                         0
# 15988                                         0
# 15994                                         0
# 16000                                         0
#
#        GEO_Dawson Creek, Census agglomeration (CA)  \
# 4                                                0
# 10                                               0
# 16                                               0
# 22                                               0
# 28                                               0
# ...                                            ...
# 15976                                            0
# 15982                                            0
# 15988                                            0
# 15994                                            0
# 16000                                            0
#
#        GEO_Duncan, Census agglomeration (CA)  ...  \
# 4                                          0  ...
# 10                                         0  ...
# 16                                         0  ...
# 22                                         0  ...
# 28                                         0  ...
# ...                                      ...  ...
# 15976                                      0  ...
# 15982                                      0  ...
# 15988                                      0  ...
# 15994                                      0  ...
# 16000                                      0  ...
#
#        Property characteristics_Other property type  \
# 4                                                 0
# 10                                                0
# 16                                                0
# 22                                                0
# 28                                                0
# ...                                             ...
# 15976                                             0
# 15982                                             0
# 15988                                             0
# 15994                                             0
# 16000                                             0
#
#        Property characteristics_Period of construction not applicable (vacant land)  \
# 4                                                      0
# 10                                                     0
# 16                                                     0
# 22                                                     0
# 28                                                     0
# ...                                                  ...
# 15976                                                  0
# 15982                                                  0
# 15988                                                  0
# 15994                                                  0
# 16000                                                  1
#
#        Property characteristics_Property with multiple residential units  \
# 4                                                      0
# 10                                                     0
# 16                                                     0
# 22                                                     0
# 28                                                     0
# ...                                                  ...
# 15976                                                  0
# 15982                                                  0
# 15988                                                  0
# 15994                                                  0
# 16000                                                  0
#
#        Property characteristics_Row house  \
# 4                                       0
# 10                                      0
# 16                                      0
# 22                                      1
# 28                                      0
# ...                                   ...
# 15976                                   0
# 15982                                   0
# 15988                                   0
# 15994                                   0
# 16000                                   0
#
#        Property characteristics_Semi-detached house  \
# 4                                                 0
# 10                                                0
# 16                                                1
# 22                                                0
# 28                                                0
# ...                                             ...
# 15976                                             0
# 15982                                             0
# 15988                                             0
# 15994                                             0
# 16000                                             0
#
#        Property characteristics_Single-detached house  \
# 4                                                   0
# 10                                                  1
# 16                                                  0
# 22                                                  0
# 28                                                  0
# ...                                               ...
# 15976                                               0
# 15982                                               0
# 15988                                               0
# 15994                                               0
# 16000                                               0
#
#        Property characteristics_Total, all periods of construction  \
# 4                                                      0
# 10                                                     0
# 16                                                     0
# 22                                                     0
# 28                                                     0
# ...                                                  ...
# 15976                                                  0
# 15982                                                  0
# 15988                                                  0
# 15994                                                  0
# 16000                                                  0
#
#        Property characteristics_Total, all property types  \
# 4                                                      1
# 10                                                     0
# 16                                                     0
# 22                                                     0
# 28                                                     0
# ...                                                  ...
# 15976                                                  0
# 15982                                                  0
# 15988                                                  0
# 15994                                                  0
# 16000                                                  0
#
#        Property characteristics_Unspecified period of construction  \
# 4                                                      0
# 10                                                     0
# 16                                                     0
# 22                                                     0
# 28                                                     0
# ...                                                  ...
# 15976                                                  0
# 15982                                                  0
# 15988                                                  0
# 15994                                                  0
# 16000                                                  0
#
#        Property characteristics_Vacant land
# 4                                         0
# 10                                        0
# 16                                        0
# 22                                        0
# 28                                        0
# ...                                     ...
# 15976                                     0
# 15982                                     0
# 15988                                     0
# 15994                                     0
# 16000                                     0
#
# [1586 rows x 64 columns]

# %%
Y = r_df_sales['PRICE']
Y
# Out:
# 4        200000.0
# 10       220000.0
# 16       200000.0
# 22       280000.0
# 28       250000.0
#            ...
# 15976    590000.0
# 15982    530000.0
# 15988    640000.0
# 15994    470000.0
# 16000    220000.0
# Name: PRICE, Length: 1586, dtype: float64

# %%
Y.median()
# Out:
# 320000.0

# %%
print(len(X))
print(len(Y))
# Out:
# 1586
# 1586

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.4, random_state=101)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (951, 64)
# (635, 64)
# (951,)
# (635,)

# %%
#we can see here that the price of a home with all values being zero is expected to be $639,458 - dam that's high 
lr = LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)
# Out:
# 0.8346827745890846

# %%
print(round(lr.intercept_))
# Out:
# 639458.0

# %%
#coefficient parameters
coeff_parameter = pd.DataFrame(lr.coef_,X.columns,columns=['Coefficient'])
coeff_parameter
# Out:
#                                                       Coefficient
# GEO_Bathurst, Census agglomeration (CA)            -538235.478141
# GEO_British Columbia                                 44233.038361
# GEO_Campbell River, Census agglomeration (CA)      -250313.865912
# GEO_Campbellton (New Brunswick part), Census ag... -540337.392765
# GEO_Cape Breton, Census agglomeration (CA)         -522655.525136
# ...                                                           ...
# Property characteristics_Single-detached house       77250.513671
# Property characteristics_Total, all periods of ...  -12475.134372
# Property characteristics_Total, all property types  -10039.405594
# Property characteristics_Unspecified period of ...    2892.118632
# Property characteristics_Vacant land                -80094.724527
#
# [64 rows x 1 columns]

# %% [markdown]
# We can see here which variables have a positive relationship with the target variable price for example the price tends to go up if
# its GEO tag is british columbia (no surprise) but the price tends to drop when if it is vacant land

# %%
#lets make some predictions 
lr_prediction = lr.predict(x_test)
lr_prediction[10]
#do this as well:lr_predi
# Out:
# 258341.3145653843

# %%
sns.regplot(y_test,lr_prediction)
# Out:
# C:\Users\owner\anaconda3\envs\ml_env\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
cross_val_score(LinearRegression(), X, Y, cv=cv)
# Out:
# array([0.80777355, 0.85542278, 0.8287895 , 0.84031791, 0.81988306])

# %%
#
x_train_sm = sm.add_constant(x_train)

x_train_sm = sm.add_constant(x_train)
ls = sm.OLS(y_train,x_train_sm).fit()
print(ls.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PRICE   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.832
# Method:                 Least Squares   F-statistic:                     74.42
# Date:                Mon, 14 Mar 2022   Prob (F-statistic):          7.94e-311
# Time:                        20:57:01   Log-Likelihood:                -12367.
# No. Observations:                 951   AIC:                         2.486e+04
# Df Residuals:                     886   BIC:                         2.518e+04
# Df Model:                          64
# Covariance Type:            nonrobust
# =====================================================================================================================================================
#                                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                              6.395e+05    2.8e+04     22.801      0.000    5.84e+05    6.95e+05
# GEO_Bathurst, Census agglomeration (CA)                                           -5.382e+05   3.45e+04    -15.620      0.000   -6.06e+05   -4.71e+05
# GEO_British Columbia                                                               4.423e+04   3.27e+04      1.354      0.176   -1.99e+04    1.08e+05
# GEO_Campbell River, Census agglomeration (CA)                                     -2.503e+05   3.37e+04     -7.422      0.000   -3.17e+05   -1.84e+05
# GEO_Campbellton (New Brunswick part), Census agglomeration (CA) – provincial part -5.403e+05      4e+04    -13.512      0.000   -6.19e+05   -4.62e+05
# GEO_Cape Breton, Census agglomeration (CA)                                        -5.227e+05   3.38e+04    -15.459      0.000   -5.89e+05   -4.56e+05
# GEO_Chilliwack, Census agglomeration (CA)                                         -1.115e+05   3.23e+04     -3.448      0.001   -1.75e+05   -4.81e+04
# GEO_Courtenay, Census agglomeration (CA)                                          -1.929e+05   3.26e+04     -5.911      0.000   -2.57e+05   -1.29e+05
# GEO_Cranbrook, Census agglomeration (CA)                                          -3.174e+05   3.42e+04     -9.274      0.000   -3.85e+05    -2.5e+05
# GEO_Dawson Creek, Census agglomeration (CA)                                        -3.74e+05   3.53e+04    -10.599      0.000   -4.43e+05   -3.05e+05
# GEO_Duncan, Census agglomeration (CA)                                             -2.422e+05   3.26e+04     -7.435      0.000   -3.06e+05   -1.78e+05
# GEO_Edmundston, Census agglomeration (CA)                                         -5.265e+05   3.81e+04    -13.805      0.000   -6.01e+05   -4.52e+05
Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8900.429
# Skew:                           1.293   Prob(JB):                         0.00
# Kurtosis:                      17.763   Cond. No.                         51.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#we even got 99% lets compare to decision tree 
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,Y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,Y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,Y)
# Out:
#                model  best_score  \
# 0  linear_regression    0.830437
# 1              lasso    0.830462
# 2      decision_tree    0.735196
#
#                                          best_params
# 0                                {'normalize': True}
# 1                {'alpha': 2, 'selection': 'cyclic'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
# Visualize the relationships between all measures
_ = pd.plotting.scatter_matrix(r_df_sales, figsize=(4,4))

# %%
# Visualize the relationships between all measures
r_df_sales.corr()
# Out:
#        PRICE
# PRICE    1.0

# %%
#lets plot the residuals 
plot_scatter

# %%
#lets predict average buyers 
avg_buyers
#X = cdn_df3[['GEO', 'Sale type', 'Property characteristics', 'Estimates']]
X_buyers = avg_buyers
X_buyers = pd.get_dummies(data=X, drop_first=True)
X_buyers
# Out:
#        VALUE  GEO_Bathurst, Census agglomeration (CA)  GEO_British Columbia  \
# 3        1.6                                        0                     0
# 9        1.7                                        0                     0
# 15       1.5                                        0                     0
# 21       1.6                                        0                     0
# 27       1.5                                        0                     0
# ...      ...                                      ...                   ...
# 15975    1.7                                        0                     0
# 15981    1.7                                        0                     0
# 15987    1.7                                        0                     0
# 15993    1.7                                        0                     0
# 15999    1.6                                        0                     0
#
#        GEO_Campbell River, Census agglomeration (CA)  \
# 3                                                  0
# 9                                                  0
# 15                                                 0
# 21                                                 0
# 27                                                 0
# ...                                              ...
# 15975                                              0
# 15981                                              0
# 15987                                              0
# 15993                                              0
# 15999                                              0
#
#        GEO_Campbellton (New Brunswick part), Census agglomeration (CA) – provincial part  \
# 3                                                      0
# 9                                                      0
# 15                                                     0
# 21                                                     0
# 27                                                     0
# ...                                                  ...
# 15975                                                  0
# 15981                                                  0
# 15987                                                  0
# 15993                                                  0
# 15999                                                  0
#
#        GEO_Cape Breton, Census agglomeration (CA)  \
# 3                                               0
# 9                                               0
# 15                                              0
# 21                                              0
# 27                                              0
# ...                                           ...
# 15975                                           0
# 15981                                           0
# 15987                                           0
# 15993                                           0
# 15999                                           0
#
#        GEO_Chilliwack, Census agglomeration (CA)  \
# 3                                              0
# 9                                              0
# 15                                             0
# 21                                             0
# 27                                             0
# ...                                          ...
# 15975                                          0
# 15981                                          0
# 15987                                          0
# 15993                                          0
# 15999                                          0
#
#        GEO_Courtenay, Census agglomeration (CA)  \
# 3                                             0
# 9                                             0
# 15                                            0
# 21                                            0
# 27                                            0
# ...                                         ...
# 15975                                         0
# 15981                                         0
# 15987                                         0
# 15993                                         0
# 15999                                         0
#
#        GEO_Cranbrook, Census agglomeration (CA)  \
# 3                                             0
# 9                                             0
# 15                                            0
# 21                                            0
# 27                                            0
# ...                                         ...
# 15975                                         0
# 15981                                         0
# 15987                                         0
# 15993                                         0
# 15999                                         0
#
#        GEO_Dawson Creek, Census agglomeration (CA)  ...  \
# 3                                                0  ...
# 9                                                0  ...
# 15                                               0  ...
# 21                                               0  ...
# 27                                               0  ...
# ...                                            ...  ...
# 15975                                            0  ...
# 15981                                            0  ...
# 15987                                            0  ...
# 15993                                            0  ...
# 15999                                            0  ...
#
#        Property characteristics_Other property type  \
# 3                                                 0
# 9                                                 0
# 15                                                0
# 21                                                0
# 27                                                0
# ...                                             ...
# 15975                                             0
# 15981                                             0
# 15987                                             0
# 15993                                             0
# 15999                                             0
#
#        Property characteristics_Period of construction not applicable (vacant land)  \
# 3                                                      0
# 9                                                      0
# 15                                                     0
# 21                                                     0
# 27                                                     0
# ...                                                  ...
# 15975                                                  0
# 15981                                                  0
# 15987                                                  0
# 15993                                                  0
# 15999                                                  1
#
#        Property characteristics_Property with multiple residential units  \
# 3                                                      0
# 9                                                      0
# 15                                                     0
# 21                                                     0
# 27                                                     0
# ...                                                  ...
# 15975                                                  0
# 15981                                                  0
# 15987                                                  0
# 15993                                                  0
# 15999                                                  0
#
#        Property characteristics_Row house  \
# 3                                       0
# 9                                       0
# 15                                      0
# 21                                      1
# 27                                      0
# ...                                   ...
# 15975                                   0
# 15981                                   0
# 15987                                   0
# 15993                                   0
# 15999                                   0
#
#        Property characteristics_Semi-detached house  \
# 3                                                 0
# 9                                                 0
# 15                                                1
# 21                                                0
# 27                                                0
# ...                                             ...
# 15975                                             0
# 15981                                             0
# 15987                                             0
# 15993                                             0
# 15999                                             0
#
#        Property characteristics_Single-detached house  \
# 3                                                   0
# 9                                                   1
# 15                                                  0
# 21                                                  0
# 27                                                  0
# ...                                               ...
# 15975                                               0
# 15981                                               0
# 15987                                               0
# 15993                                               0
# 15999                                               0
#
#        Property characteristics_Total, all periods of construction  \
# 3                                                      0
# 9                                                      0
# 15                                                     0
# 21                                                     0
# 27                                                     0
# ...                                                  ...
# 15975                                                  0
# 15981                                                  0
# 15987                                                  0
# 15993                                                  0
# 15999                                                  0
#
#        Property characteristics_Total, all property types  \
# 3                                                      1
# 9                                                      0
# 15                                                     0
# 21                                                     0
# 27                                                     0
# ...                                                  ...
# 15975                                                  0
# 15981                                                  0
# 15987                                                  0
# 15993                                                  0
# 15999                                                  0
#
#        Property characteristics_Unspecified period of construction  \
# 3                                                      0
# 9                                                      0
# 15                                                     0
# 21                                                     0
# 27                                                     0
# ...                                                  ...
# 15975                                                  0
# 15981                                                  0
# 15987                                                  0
# 15993                                                  0
# 15999                                                  0
#
#        Property characteristics_Vacant land
# 3                                         0
# 9                                         0
# 15                                        0
# 21                                        0
# 27                                        0
# ...                                     ...
# 15975                                     0
# 15981                                     0
# 15987                                     0
# 15993                                     0
# 15999                                     0
#
# [2280 rows x 66 columns]

# %%
Y_buyers = avg_buyers['VALUE']
Y_buyers
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.4, random_state=101)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
#make sure these are the right sizes and shape for fitting
# Out:
# (1368, 66)
# (912, 66)
# (1368,)
# (912,)

# %%
lr_buyers = LinearRegression()
lr_buyers.fit(x_train,y_train)
print(round(lr_buyers.intercept_))
# Out:
# 0.0

# %%
coeff_parameter = pd.DataFrame(lr.coef_,X.columns,columns=['Coefficient'])
coeff_parameter
# Out:
#                                                      Coefficient
# VALUE                                               1.000000e+00
# GEO_Bathurst, Census agglomeration (CA)            -2.039396e-16
# GEO_British Columbia                               -2.810583e-17
# GEO_Campbell River, Census agglomeration (CA)      -7.514624e-18
# GEO_Campbellton (New Brunswick part), Census ag... -6.205421e-17
# ...                                                          ...
# Property characteristics_Single-detached house      2.986969e-17
# Property characteristics_Total, all periods of ... -1.002842e-17
# Property characteristics_Total, all property types  6.052939e-17
# Property characteristics_Unspecified period of ... -6.388029e-17
# Property characteristics_Vacant land                2.184892e-17
#
# [66 rows x 1 columns]

# %%
lr_prediction_buyers = lr.predict(x_test)
sns.regplot(y_test,lr_prediction_buyers)
# Out:
# C:\Users\owner\anaconda3\envs\ml_env\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x_train_sm = sm.add_constant(x_train)

x_train_sm = sm.add_constant(x_train)
ls = sm.OLS(y_train,x_train_sm).fit()
print(ls.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  VALUE   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.372e+29
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):               0.00
# Time:                
# Property characteristics_1981 to 1990                                              -2.22e-16   8.77e-16     -0.253      0.800   -1.94e-15     1.5e-15
# Property characteristics_1991 to 2000                                              -1.52e-15   8.79e-16     -1.728      0.084   -3.24e-15    2.06e-16
# Property characteristics_2001 to 2005                                             -2.776e-17   9.38e-16     -0.030      0.976   -1.87e-15    1.81e-15
# Property characteristics_2006 to 2010                                              3.747e-16   9.66e-16      0.388      0.698   -1.52e-15    2.27e-15
# Property characteristics_2011 to 2015                                             -1.388e-16   9.03e-16     -0.154      0.878   -1.91e-15    1.63e-15
# Property characteristics_2016 to reference period                                  -1.11e-16    9.2e-16     -0.121      0.904   -1.92e-15    1.69e-15
# Property characteristics_Condominium apartment                                     5.829e-16   9.39e-16      0.621      0.535   -1.26e-15    2.43e-15
# Property characteristics_Mobile homes                                             -2.082e-16   9.18e-16     -0.227      0.821   -2.01e-15    1.59e-15
# Property characteristics_Other property type                                       1.804e-16   1.11e-15      0.162      0.871      -2e-15    2.36e-15
# Property characteristics_Period of construction not applicable (vacant land)       -1.11e-16   8.92e-16     -0.124      0.901   -1.86e-15    1.64e-15
# Property characteristics_Property with multiple residential units                 -3.469e-17   8.67e-16     -0.040      0.968   -1.74e-15    1.67e-15
# Property characteristics_Row house                                                -4.094e-16   1.02e-15     -0.402      0.688   -2.41e-15    1.59e-15
# Property characteristics_Semi-detached house                                      -2.429e-17   1.05e-15     -0.023      0.982   -2.09e-15    2.04e-15
# Property characteristics_Single-detached house                                    -3.331e-16   9.14e-16     -0.364      0.716   -2.13e-15    1.46e-15
# Property characteristics_Total, all periods of construction                        2.498e-16   8.88e-16      0.281      0.779   -1.49e-15    1.99e-15
# Property characteristics_Total, all property types                                -3.747e-16   8.94e-16     -0.419      0.675   -2.13e-15    1.38e-15
# Property characteristics_Unspecified period of construction                       -2.984e-16    1.6e-15     -0.186      0.852   -3.44e-15    2.84e-15
# Property characteristics_Vacant land                                               1.388e-16   8.95e-16      0.155      0.877   -1.62e-15    1.89e-15
# ==============================================================================
# Omnibus:                     2379.256   Durbin-Watson:                   0.171
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3534842.468
# Skew:                          11.384   Prob(JB):                         0.00
# Kurtosis:                     250.985   Cond. No.                         93.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_prop = prop_sold
X_prop = pd.get_dummies(data=X_prop, drop_first=True)
Y_prop = prop_sold['VALUE']
Y_prop
x_train,x_test,y_train,y_test = train_test_split(X_prop,Y_prop, test_size=0.4, random_state=101)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
#make sure these are the right sizes and shape for fitting
# Out:
# (1600, 66)
# (1067, 66)
# (1600,)
# (1067,)

# %%
lr_prop = LinearRegression()
lr_prop.fit(x_train,y_train)
print(round(lr_prop.intercept_))
# Out:
# -0.0

# %%
coeff_parameter = pd.DataFrame(lr_prop.coef_,X.columns,columns=['Coefficient'])
coeff_parameter
# Out:
#                                                      Coefficient
# VALUE                                               1.000000e+00
# GEO_Bathurst, Census agglomeration (CA)            -1.918225e-12
# GEO_British Columbia                                2.429123e-12
# GEO_Campbell River, Census agglomeration (CA)      -1.867504e-12
# GEO_Campbellton (New Brunswick part), Census ag... -3.239169e-12
# ...                                                          ...
# Property characteristics_Single-detached house      6.486298e-13
# Property characteristics_Total, all periods of ... -3.461939e-11
# Property characteristics_Total, all property types  1.542954e-12
# Property characteristics_Unspecified period of ...  6.075527e-13
# Property characteristics_Vacant land                2.504877e-12
#
# [66 rows x 1 columns]

# %%
lr_prediction_prop = lr.predict(x_test)
sns.regplot(y_test,lr_prediction_prop)
# Out:
# C:\Users\owner\anaconda3\envs\ml_env\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x_train_sm = sm.add_constant(x_train)

x_train_sm = sm.add_constant(x_train)
ls = sm.OLS(y_train,x_train_sm).fit()
print(ls.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  VALUE   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.379e+31
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):               0.00
# Time:                        13:16:01   Log-Likelihood:                 38854.
# No. Observations:                1600   AIC:                        -7.757e+04
# Df Residuals:                    1533   BIC:                        -7.721e+04
# Df Model:                          66
# Covariance Type:            nonrobust
# =====================================================================================================================================================
#                                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                             -2.309e-13   1.45e-12     -0.159      0.873   -3.07e-12    2.61e-12
# VALUE                                                                                 1.0000   3.97e-17   2.52e+16      0.000       1.000       1.000
# GEO_Bathurst, Census agglomeration (CA)                                             2.16e-12   1.76e-12      1.230      0.219   -1.28e-12     5.6e-12
# GEO_British Columbia                                                              -9.095e-12    1.8e-12     -5.056      0.000   -1.26e-11   -5.57e-12
# GEO_Campbell River, Census agglomeration (CA)                                     -3.126e-13   1.65e-12     -0.189      0.850   -3.55e-12    2.93e-12
# GEO_Campbellton (New Brunswick part), Census agglomeration (CA) – provincial part  1.137e-12   1.68e-12      0.678      0.498   -2.15e-12    4.43e-12
# GEO_Cape Breton, Census agglomeration (CA)                                         1.847e-13   1.66e-12      0.111      0.912   -3.08e-12    3.45e-12
# GEO_Chilliwack, Census agglomeration (CA)                                          3.979e-13   1.78e-12      0.223      0.823    -3.1e-12    3.89e-12
# GEO_Courtenay, Census agglomeration (CA)                                           2.558e-13   1.68e-12      0.152      0.879   -3.05e-12    3.56e-12
# GEO_Cranbrook, Census agglomeration (CA)                                           7.674e-13   1.75e-12      0.438      0.661   -2.67e-12     4.2e-12
# GEO_Dawson Creek, Census agglomeration (CA)                                       -9.663e-13   1.68e-12     -0.574      0.566   -4.27e-12    2.33e-12
# GEO_Duncan, Census agglomeration (CA)                                              -1.99e-13   1.66e-12     -0.120      0.905   -3.46e-12    3.06e-12
# GEO_Edmundston, Census agglomeration (CA)                                         -2.842e-13   1.67e-12     -0.171      0.864   -3.55e-12    2.98e-12
# GEO_Fort St. John, Census agglomeration (CA)                                       1.535e-12   1.65e-12      0.927      0.354   -1.71e-12    4.78e-12
# GEO_Fredericton, Census agglomeration (CA)                                         -1.99e-13    1.6e-12     -0.125      0.901   -3.33e-12    2.93e-12
# GEO_Halifax, Census metropolitan area (CMA)                                       -4.547e-13   1.74e-12     -0.262      0.793   -3.86e-12    2.95e-12
# GEO_Kamloops, Census agglomeration (CA)                                            1.492e-13   1.67e-12      0.089      0.929   -3.13e-12    3.43e-12
# GEO_Kelowna, Census metropolitan area (CMA)                                        6.821e-13   1.71e-12      0.399      0.690   -2.67e-12    4.03e-12
# GEO_Kentville, Census agglomeration (CA)                                          -7.674e-13   1.88e-12     -0.409      0.683   -4.45e-12    2.92e-12
+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.49e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#lets get all the estimate and values to append 
cdn_df2['Estimates']

# %%
r_df_sales.shape
#so we have only 1586 values for avg sales price
# Out:
# (1586, 5)

# %%
#now we have our dataframe but we should include more features from original df from estimates col with avg buyers, etc. as these could
#really help predict what the sale price of the house is, we need to merge these into this df
#let's first extract that cols as a series and then merge into this df with its value aligned

# %%
#values are definitely rounded, not sure why it is called avg other than perhaps it's because there can be more than one sale at once
avg_sale_price['VALUE'].unique()
# Out:
# array([ 200000.,  220000.,  280000.,  250000.,   68000.,  350000.,
#         430000.,   62000.,  173000.,  161000.,  210000.,  310000.,
#         320000.,  330000.,  390000.,   99000.,  123000.,   28000.,
#          41000.,  125000.,   23000.,   84000.,  103000.,  129000.,
#         159000.,  182000.,  230000.,  240000.,  132000.,  260000.,
#         101000.,  760000.,  120000.,  370000.,  270000.,  300000.,
#         380000.,  510000.,  192000.,  160000.,   66000.,  150000.,
#         154000.,  176000.,  197000.,  290000.,  122000.,  135000.,
#          55000.,  134000.,   38000.,   79000.,  124000.,  180000.,
#          70000.,  143000.,  158000.,  127000.,   67000.,   48000.,
#         128000.,  140000.,  139000.,  184000.,  107000.,  133000.,
#         157000.,  181000.,  167000.,   44000.,  149000.,  156000.,
#         148000.,  177000.,  172000.,  168000.,   63000.,   35000.,
#         146000.,  137000.,  190000.,   45000.,  131000.,   17700.,
#          74000.,   94000.,  104000.,  187000.,   96000.,   56000.,
#          16600.,   77000.,   98000.,   89000.,  118000.,   82000.,
#          37000.,   80000.,  191000.,   72000.,   50000.,  186000.,
#         106000.,   61000.,  166000.,  147000.,  195000.,   97000.,
#         183000.,  163000.,   57000.,   76000.,  144000.,  175000.,
#         171000.,  189000.,  188000.,  198000.,   46000.,  151000.,
#         170000.,  199000.,  105000.,   65000.,   91000.,  169000.,
#         117000.,   69000.,  720000.,  840000.,  610000.,  550000.,
#         730000., 1280000.,  470000., 1000000.,  920000.,  650000.,
#         710000.,  660000.,  820000.,  680000.,  690000.,  870000.,
#         480000.,  830000.,  580000.,  890000.,  750000.,  620000.,
#         540000.,  530000.,  590000.,  410000.,  360000.,  640000.,
#         340000.,  450000.,  490000.,  570000.,  500000.,  520000.,
#         440000.,  740000.,  460000.,  630000.,  420000.,  400000.,
#         780000.,  560000.,  600000.,  185000.,   47000., 1060000.,
#        1250000., 1450000.,  900000.,  790000.,  800000.,  136000.,
#         178000., 1690000., 2000000., 1910000., 1480000., 1990000.,
#        1070000.,  960000., 1040000.,  970000.,  770000.,  700000.,
#         910000.,  930000.,  850000.,  670000.])

# %%
#luckily all the values look reasonable and we can work with
#now create a new column for avg sale price 
avg_sale_price.shape
# Out:
# (1586, 10)

# %%
avg_num_prop_mask = cdn_df3["Estimates"]=="Number of properties sold"
avg_num_prop = cdn_df3[avg_num_prop_mask]
avg_num_prop.head(10)
# Out:
#     REF_DATE          GEO              Sale type  \
# 0       2018  Nova Scotia  Total, all sale types
# 6       2018  Nova Scotia  Total, all sale types
# 12      2018  Nova Scotia  Total, all sale types
# 18      2018  Nova Scotia  Total, all sale types
# 24      2018  Nova Scotia  Total, all sale types
# 30      2018  Nova Scotia  Total, all sale types
# 36      2018  Nova Scotia  Total, all sale types
# 42      2018  Nova Scotia  Total, all sale types
# 48      2018  Nova Scotia  Total, all sale types
# 54      2018  Nova Scotia  Total, all sale types
#
#                     Property characteristics                  Estimates  \
# 0                  Total, all property types  Number of properties sold
# 6                      Single-detached house  Number of properties sold
# 9738      2018  Kelowna, Census metropolitan area (CMA)
# 9744      2018  Kelowna, Census metropolitan area (CMA)
# 9750      2018  Kelowna, Census metropolitan area (CMA)
# 9756      2018  Kelowna, Census metropolitan area (CMA)
# 9762      2018  Kelowna, Census metropolitan area (CMA)
# 9768      2018  Kelowna, Census metropolitan area (CMA)
# 9774      2018  Kelowna, Census metropolitan area (CMA)
# 9780      2018  Kelowna, Census metropolitan area (CMA)
# 9786      2018  Kelowna, Census metropolitan area (CMA)
# 9792      2018  Kelowna, Census metropolitan area (CMA)
# 9798      2018  Kelowna, Census metropolitan area (CMA)
# 9804      2018  Kelowna, Census metropolitan area (CMA)
# 9810      2018  Kelowna, Census metropolitan area (CMA)
# 9816      2018  Kelowna, Census metropolitan area (CMA)
# 9822      2018  Kelowna, Census metropolitan area (CMA)
# 9828      2018  Kelowna, Census metropolitan area (CMA)
# 9834      2018  Kelowna, Census metropolitan area (CMA)
# 9840      2018  Kelowna, Census metropolitan area (CMA)
# 9846      2018  Kelowna, Census metropolitan area (CMA)
# 9852      2018  Kelowna, Census metropolitan area (CMA)
# 9858      2018  Kelowna, Census metropolitan area (CMA)
# 9864      2018  Kelowna, Census metropolitan area (CMA)
# 9870      2018  Kelowna, Census metropolitan area (CMA)
# 9876      2018  Kelowna, Census metropolitan area (CMA)
#
#                   Sale type  \
# 9522  Total, all sale types
# 9528  Total, all sale types
# 9534  Total, all sale types
# 9540  Total, all sale types
# 9546  Total, all sale types
# 9552  Total, all sale types
# 9558  Total, all sale types
# 9564  Total, all sale types
# 9570  Total, all sale types
# 9576  Total, all sale types
# 9582  Total, all sale types
# 9588  Total, all sale types
# 9594  Total, all sale types
# 9600  Total, all sale types
# 9606  Total, all sale types
# 9612  Total, all sale types
# 9618  Total, all sale types
# 9624  Total, all sale types
# 9630  Total, all sale types
# 9636  Total, all sale types
# 9642        Non-market sale
# 9648        Non-market sale
# 9654        Non-market sale
# 9660        Non-market sale
# 9666        Non-market sale
# 9672        Non-market sale
# 9678        Non-market sale
# 9684        Non-market sale
# 9690        Non-market sale
# 9696        Non-market sale
# 9702        Non-market sale
# 9708        Non-market sale
# 9714        Non-market sale
# 9720        Non-market sale
# 9726        Non-market sale
# 9732        Non-market sale
# 9738        Non-market sale
# 9744        Non-market sale
# 9750        Non-market sale
# 9756        Non-market sale
# 9762            Market sale
# 9768            Market sale
# 9774            Market sale
# 9780            Market sale
# 9786            Market sale
# 9792            Market sale
# 9798            Market sale
# 9804            Market sale
# 9810            Market sale
# 9816            Market sale
# 9822            Market sale
# 9828            Market sale
# 9834            Market sale
# 9840            Market sale
# 9846            Market sale
# 9852            Market sale
# 9858            Market sale
# 9864            Market sale
# 9870            Market sale
# 9876            Market sale
#
#                                Property characteristics  \
# 9522                          Total, all property types
# 9528                              Single-detached house
# 9534                                Semi-detached house
# 9540                                          Row house
# 9546                              Condominium apartment
# 9552                                       Mobile homes
# 9558                                Other property type
# 9564           Property with multiple residential units
# 9570                                        Vacant land
# 9576                 Total, all periods of construction
# 9582                                    1960 or earlier
# 9588                                       1961 to 1970
# 9594                                       1971 to 1980
# 9600                                       1981 to 1990
# 9606                                       1991 to 2000
# 9612                                       2001 to 2005
# 9618                                       2006 to 2010
# 9624                                       2011 to 2015
# 9630                           2016 to reference period
# 9636  Period of construction not applicable (vacant ...
# 9642                          Total, all property types
# 9648                              Single-detached house
# 9654                                Semi-detached house
# 9660                                          Row house
# 9666                              Condominium apartment
# 9672                                       Mobile homes
# 9678                                Other property type
# 9684           Property with multiple residential units
# 9690                                        Vacant land
# 9696                 Total, all periods of construction
# 9702                                    1960 or earlier
# 9708                                       1961 to 1970
# 9714                                       1971 to 1980
# 9720                                       1981 to 1990
# 9726                                       1991 to 2000
# 9732                                       2001 to 2005
# 9738                                       2006 to 2010
# 9744                                       2011 to 2015
# 9750                           2016 to reference period
# 9756  Period of construction not applicable (vacant ...
# 9762                          Total, all property types
# 9768                              Single-detached house
# 9774                                Semi-detached house
# 9780                                          Row house
# 9786                              Condominium apartment
# 9792                                       Mobile homes
# 9798                                Other property type
# 9804           Property with multiple residential units
# 9810                                        Vacant land
# 9816                 Total, all periods of construction
# 9822                                    1960 or earlier
# 9828                                       1961 to 1970
# 9834                                       1971 to 1980
# 9840                                       1981 to 1990
# 9846                                       1991 to 2000
# 9852                                       2001 to 2005
# 9858                                       2006 to 2010
# 9864                                       2011 to 2015
# 9870                           2016 to reference period
# 9876  Period of construction not applicable (vacant ...
#
#                       Estimates     UOM  UOM_ID COORDINATE   VALUE  DECIMALS
# 9522  Number of properties sold  Number     223   27.1.1.1  7120.0         0
# 9528  Number of properties sold  Number     223   27.1.2.1  2870.0         0
# 9534  Number of properties sold  Number     223   27.1.3.1   190.0         0
# 9540  Number of properties sold  Number     223   27.1.4.1   870.0         0
# 9546  Number of properties sold  Number     223   27.1.5.1  1955.0         0
# 9552  Number of properties sold  Number     223   27.1.6.1    25.0         0
# 9558  Number of properties sold  Number     223   27.1.7.1   135.0         0
# 9564  Number of properties sold  Number     223   27.1.8.1   640.0         0
# 9570  Number of properties sold  Number     223   27.1.9.1   435.0         0
# 9576  Number of properties sold  Number     223  27.1.10.1  7120.0         0
# 9582  Number of properties sold  Number     223  27.1.11.1   280.0         0
# 9588  Number of properties sold  Number     223  27.1.12.1   380.0         0
# 9594  Number of properties sold  Number     223  27.1.13.1   885.0         0
# 9600  Number of properties sold  Number     223  27.1.14.1   760.0         0
# 9606  Number of properties sold  Number     223  27.1.15.1  1030.0         0
# 9612  Number of properties sold  Number     223  27.1.16.1   625.0         0
# 9618  Number of properties sold  Number     223  27.1.17.1  1035.0         0
# 9624  Number of properties sold  Number     223  27.1.18.1   345.0         0
# 9630  Number of properties sold  Number     223  27.1.19.1  1345.0         0
# 9636  Number of properties sold  Number     223  27.1.21.1   435.0         0
# 9642  Number of properties sold  Number     223   27.2.1.1  1390.0         0
# 9648  Number of properties sold  Number     223   27.2.2.1   770.0         0
# 9654  Number of properties sold  Number     223   27.2.3.1    45.0         0
# 9660  Number of properties sold  Number     223   27.2.4.1   125.0         0
# 9666  Number of properties sold  Number     223   27.2.5.1   200.0         0
# 9672  Number of properties sold  Number     223   27.2.6.1    10.0         0
# 9678  Number of properties sold  Number     223   27.2.7.1    30.0         0
# 9684  Number of properties sold  Number     223   27.2.8.1   155.0         0
# 9690  Number of properties sold  Number     223   27.2.9.1    55.0         0
# 9696  Number of properties sold  Number     223  27.2.10.1  1390.0         0
# 9702  Number of properties sold  Number     223  27.2.11.1   100.0         0
# 9708  Number of properties sold  Number     223  27.2.12.1   120.0         0
# 9714  Number of properties sold  Number     223  27.2.13.1   275.0         0
# 9720  Number of properties sold  Number     223  27.2.14.1   185.0         0
# 9726  Number of properties sold  Number     223  27.2.15.1   250.0         0
# 9732  Number of properties sold  Number     223  27.2.16.1   145.0         0
# 9738  Number of properties sold  Number     223  27.2.17.1   135.0         0
# 9744  Number of properties sold  Number     223  27.2.18.1    55.0         0
# 9750  Number of properties sold  Number     223  27.2.19.1    75.0         0
# 9756  Number of properties sold  Number     223  27.2.21.1    55.0         0
# 9762  Number of properties sold  Number     223   27.3.1.1  5730.0         0
# 9768  Number of properties sold  Number     223   27.3.2.1  2100.0         0
# 9774  Number of properties sold  Number     223   27.3.3.1   145.0         0
# 9780  Number of properties sold  Number     223   27.3.4.1   745.0         0
# 9786  Number of properties sold  Number     223   27.3.5.1  1755.0         0
# 9792  Number of properties sold  Number     223   27.3.6.1    15.0         0
# 9798  Number of properties sold  Number     223   27.3.7.1   105.0         0
# 9804  Number of properties sold  Number     223   27.3.8.1   485.0         0
# 9810  Number of properties sold  Number     223   27.3.9.1   380.0         0
# 9816  Number of properties sold  Number     223  27.3.10.1  5730.0         0
# 9822  Number of properties sold  Number     223  27.3.11.1   180.0         0
# 9828  Number of properties sold  Number     223  27.3.12.1   260.0         0
# 9834  Number of properties sold  Number     223  27.3.13.1   610.0         0
# 9840  Number of properties sold  Number     223  27.3.14.1   575.0         0
# 9846  Number of properties sold  Number     223  27.3.15.1   785.0         0
# 9852  Number of properties sold  Number     223  27.3.16.1   480.0         0
# 9858  Number of properties sold  Number     223  27.3.17.1   900.0         0
# 9864  Number of properties sold  Number     223  27.3.18.1   290.0         0
# 9870  Number of properties sold  Number     223  27.3.19.1  1270.0         0
# 9876  Number of properties sold  Number     223  27.3.21.1   380.0         0

# %%
prop_type_mask = avg_num_prop_kel["Property characteristics"]=="Total, all property types"
prop_type = avg_num_prop_kel[prop_type_mask]
prop_type.head()
# Out:
#       REF_DATE                                      GEO  \
# 9522      2018  Kelowna, Census metropolitan area (CMA)
# 9642      2018  Kelowna, Census metropolitan area (CMA)
# 9762      2018  Kelowna, Census metropolitan area (CMA)
#
#                   Sale type   Property characteristics  \
# 9522  Total, all sale types  Total, all property types
# 9642        Non-market sale  Total, all property types
# 9762            Market sale  Total, all property types
#
#                       Estimates     UOM  UOM_ID COORDINATE   VALUE  DECIMALS
# 9522  Number of properties sold  Number     223   27.1.1.1  7120.0         0
# 9642  Number of properties sold  Number     223   27.2.1.1  1390.0         0
# 9762  Number of properties sold  Number     223   27.3.1.1  5730.0         0

# %%
avg_num_buyers_mask = cdn_df3['Estimates']=='Average number of buyers'
avg_num_buyers = cdn_df3[avg_num_buyers_mask]
avg_num_buyers.head()
# Out:
#     REF_DATE          GEO              Sale type   Property characteristics  \
# 3       2018  Nova Scotia  Total, all sale types  Total, all property types
# 9       2018  Nova Scotia  Total, all sale types      Single-detached house
# 15      2018  Nova Scotia  Total, all sale types        Semi-detached house
# 21      2018  Nova Scotia  Total, all sale types                  Row house
# 27      2018  Nova Scotia  Total, all sale types      Condominium apartment
#
#                    Estimates     UOM  UOM_ID COORDINATE  VALUE  DECIMALS
# 3   Average number of buyers  Number     223    1.1.1.4    1.6         1
# 9   Average number of buyers  Number     223    1.1.2.4    1.7         1
# 15  Average number of buyers  Number     223    1.1.3.4    1.5         1
# 21  Average number of buyers  Number     223    1.1.4.4    1.6         1
# 27  Average number of buyers  Number     223    1.1.5.4    1.5         1

# %%
avg_num_buyers["VALUE"].unique()
# Out:
# array([ 1.6,  1.7,  1.5,  1.4,  1.8,  1.1,  1.2,  1.3,  2. ,  1.9,  3. ,
#         3.2,  2.1,  2.5,  2.6,  2.2,  2.3,  3.3,  3.1,  3.8,  9.8,  2.9,
#         2.7, 19.2,  7.5,  3.5,  2.8,  1. ,  4.1, 10.7,  5.4])

# %%
avg_num_buyers["VALUE"].unique()
#cdn_df2.groupby('Estimates')['Estimates'].agg('count')
# Out:
# array([ 1.6,  1.7,  1.5,  1.4,  1.8,  1.1,  1.2,  1.3,  2. ,  1.9,  3. ,
#         3.2,  2.1,  2.5,  2.6,  2.2,  2.3,  3.3,  3.1,  3.8,  9.8,  2.9,
#         2.7, 19.2,  7.5,  3.5,  2.8,  1. ,  4.1, 10.7,  5.4])

# %%
#rent data from: https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=3410013301 "Canada Mortgage and Housing Corporation, average rents for areas with a population of 10,000 and over"
rent_df = pd.read_csv("C:/Users/owner/Desktop/cpsc599/project/34100133-eng/34100133.csv")
rent_df.head()
# Out:
#    REF_DATE                                     GEO         DGUID  \
# 0      1987  Bay Roberts, Newfoundland and Labrador  2011S0504005
# 1      1987  Bay Roberts, Newfoundland and Labrador  2011S0504005
# 2      1987  Bay Roberts, Newfoundland and Labrador  2011S0504005
# 3      1987  Bay Roberts, Newfoundland and Labrador  2011S0504005
# 4      1987  Bay Roberts, Newfoundland and Labrador  2011S0504005
#
#                                    Type of structure         Type of unit  \
# 0  Row and apartment structures of three units an...       Bachelor units
# 1  Row and apartment structures of three units an...    One bedroom units
# 2  Row and apartment structures of three units an...    Two bedroom units
# 3  Row and apartment structures of three units an...  Three bedroom units
# 4             Row structures of three units and over       Bachelor units
#
#        UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE  \
# 0  Dollars      81         units          0  v42135513    192.3.1    NaN
# 1  Dollars      81         units          0  v42135529    192.3.2    NaN
# 2  Dollars      81         units          0  v42135545    192.3.3    NaN
# 3  Dollars      81         units          0  v42135561    192.3.4    NaN
# 4  Dollars      81         units          0  v42135577    192.2.1    NaN
#
#   STATUS  SYMBOL TERMINATED  DECIMALS
# 0     ..     NaN        NaN         0
# 1     ..     NaN        NaN         0
# 2     ..     NaN        NaN         0
# 3     ..     NaN        NaN         0
# 4     ..     NaN        NaN         0
